# %% [markdown]
# # Mushroom 🍄 Dataset's

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('Dataset/mushroom.csv')
data
# Out:
#      m_class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0          p         x           s         n       t    p               f
# 1          e         x           s         y       t    a               f
# 2          e         b           s         w       t    l               f
# 3          p         x           y         w       t    p               f
# 4          e         x           s         g       f    n               f
# ...      ...       ...         ...       ...     ...  ...             ...
# 8119       e         k           s         n       f    n               a
# 8120       e         x           s         n       f    n               a
# 8121       e         f           s         n       f    n               a
# 8122       p         k           y         n       f    y               f
# 8123       e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   m_class                   8124 non-null   object
#  1   cap-shape                 8124 non-null   object
#  2   cap-surface               8124 non-null   object
#  3   cap-color                 8124 non-null   object
#  4   bruises                   8124 non-null   object
#  5   odor                      8124 non-null   object
#  6   gill-attachment           8124 non-null   object
#  7   gill-spacing              8124 non-null   object
#  8   gill-size                 8124 non-null   object
#  9   gill-color                8124 non-null   object
#  10  stalk-shape               8124 non-null   object
#  11  stalk-root                8124 non-null   object
#  12  stalk-surface-above-ring  8124 non-null   object
# ...

# %%
data.describe()
# Out:
#        m_class cap-shape cap-surface cap-color bruises  odor gill-attachment  \
# count     8124      8124        8124      8124    8124  8124            8124
# unique       2         6           4        10       2     9               2
# top          e         x           y         n       f     n               f
# freq      4208      3656        3244      2284    4748  3528            7914
#
#        gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# count          8124      8124       8124  ...                     8124
# unique            2         2         12  ...                        4
# top               c         b          b  ...                        s
# freq           6812      5612       1728  ...                     4936
#
#        stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# count                    8124                   8124      8124       8124
# ...

# %%
data.shape
# Out:
# (8124, 23)

# %%
data['m_class'].value_counts()
# Out:
# e    4208
# p    3916
# Name: m_class, dtype: int64

# %%
# converting each column to 'category' type !!!
data = data.astype('category')
data.dtypes
# Out:
# m_class                     category
# cap-shape                   category
# cap-surface                 category
# cap-color                   category
# bruises                     category
# odor                        category
# gill-attachment             category
# gill-spacing                category
# gill-size                   category
# gill-color                  category
# stalk-shape                 category
# stalk-root                  category
# stalk-surface-above-ring    category
# stalk-surface-below-ring    category
# stalk-color-above-ring      category
# stalk-color-below-ring      category
# veil-type                   category
# veil-color                  category
# ring-number                 category
# ring-type                   category
# spore-print-color           category
# population                  category
# habitat                     category
# dtype: object

# %%
# now converting Catogerial to Ordinal value !!!

from sklearn.preprocessing import LabelEncoder

labelencoder=LabelEncoder()
for col in data.columns:
    data[col] = labelencoder.fit_transform(data[col])
    
data
# Out:
#       m_class  cap-shape  cap-surface  cap-color  bruises  odor  \
# 0           1          5            2          4        1     6
# 1           0          5            2          9        1     0
# 2           0          0            2          8        1     3
# 3           1          5            3          8        1     6
# 4           0          5            2          3        0     5
# ...       ...        ...          ...        ...      ...   ...
# 8119        0          3            2          4        0     5
# 8120        0          5            2          4        0     5
# 8121        0          2            2          4        0     5
# 8122        1          3            3          4        0     8
# 8123        0          5            2          4        0     5
#
#       gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# 0                   1             0          1           4  ...
# 1                   1             0          0           4  ...
# ...

# %%
# dropping "veil-type" as it not contributing in analysis as all are '0'

data = data.drop(['veil-type'],axis = 1)

# %%
data
# Out:
#       m_class  cap-shape  cap-surface  cap-color  bruises  odor  \
# 0           1          5            2          4        1     6
# 1           0          5            2          9        1     0
# 2           0          0            2          8        1     3
# 3           1          5            3          8        1     6
# 4           0          5            2          3        0     5
# ...       ...        ...          ...        ...      ...   ...
# 8119        0          3            2          4        0     5
# 8120        0          5            2          4        0     5
# 8121        0          2            2          4        0     5
# 8122        1          3            3          4        0     8
# 8123        0          5            2          4        0     5
#
#       gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# 0                   1             0          1           4  ...
# 1                   1             0          0           4  ...
# ...

# %%
# spliting data into ddependent and independent

x = data.iloc[:,1:23]
y = data.iloc[:,0]

# %%
# splitting trainnig dataset

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split (x , y , test_size = .20, random_state = 1)

print(x_train)
print(x_test)
print(y_train)
print(y_test)
# Out:
#       cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 1610          5            0          4        0     5                1
# 1939          5            2          3        0     5                1
# 5573          5            3          2        0     8                1
# 7076          5            2          2        0     8                1
# 2000          5            0          4        1     5                1
# ...         ...          ...        ...      ...   ...              ...
# 7935          3            3          2        0     8                1
# 5192          5            3          4        0     7                1
# 3980          2            3          3        0     2                1
# 235           5            0          8        1     3                1
# 5157          5            2          0        1     2                1
#
#       gill-spacing  gill-size  gill-color  stalk-shape  ...  \
# ...

# %%
from sklearn.tree import DecisionTreeClassifier

decision_tree = DecisionTreeClassifier(criterion = "entropy",max_depth=10)
decision_tree.fit(x_train, y_train)
predictValues =decision_tree.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
import numpy as np

print(accuracy_score(y_test, predictValues))
# Out:
# 1.0

# %%
data_feature_names = data.columns.to_list()
#data_feature_names = d1.tolist() # storing all column name to list

# !pip install graphviz
from sklearn.tree import export_graphviz
from sklearn import tree
from graphviz import Source
from IPython.display import SVG
from IPython.display import display

graph = Source(tree.export_graphviz(decision_tree, out_file=None, feature_names=data_feature_names, filled = True,rounded=True))
display(SVG(graph.pipe(format='svg')))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-401bbab6459f> in <module>
# ----> 1 d1 = data.columns.get_values()
#       2 data_feature_names = d1.tolist() # storing all column name to list
#       3
#       4 get_ipython().system('pip install graphviz')
#       5 from sklearn.tree import export_graphviz
#
# AttributeError: 'Index' object has no attribute 'get_values'

# %%
# accuracy without scalling -> 1.0
# accuracy with Min-Max -> 0.9846
# accuracy with Scaller -> 0.9861
# accuracy with PCA -> 0.9884
