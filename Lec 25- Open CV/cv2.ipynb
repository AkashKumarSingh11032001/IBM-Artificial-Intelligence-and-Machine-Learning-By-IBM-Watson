# %%
import cv2
img = cv2.imread('caps.jpg')
cv2.imshow('OutputImage',img)
cv2.waitKey(0)
#cv2.destroyAllwindows()
# Out:
# -1

# %% [markdown]
# # .waitKey(0) will display the window infinitely until any keypress (it is suitable for image display).
#
# 2.waitKey(1) will display a frame for 1 ms, after which display will be automatically closed. Since the OS has a minimum time between switching threads, the function will not wait exactly 1 ms, it will wait at least 1 ms, depending on what else is running on your computer at that time.
#
# So, if you use waitKey(0) you see a still image until you actually press something while for waitKey(1) the function will show a frame for at least 1 ms only.

# %%
import cv2
img= cv2.imread('caps.jpg')
cv2.imshow('output',img)
print(img.shape)
print("Height pixel values : ", img.shape[0])
print("Width pixel values : ", img.shape[1])

cv2.waitKey(0)
#cv2.destroyAllwindows()
# Out:
# (275, 183, 3)
# Height pixel values :  275
# Width pixel values :  183
# -1

# %%
#Example of converting RGB mage into gray scale:
import cv2
img= cv2.imread('caps.jpg')
print(img.shape)

cv2.imshow("original",img)
cv2.waitKey(0)
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
print(gray_img.shape)

# for showing image
cv2.imshow("GrayscaleImage",gray_img)
# for holding image
cv2.waitKey(0) 
# clear all windows
#cv2.destroyAllwindows()
# Out:
# (275, 183, 3)
# (275, 183)
# -1

# %%
#Example of converting RGB image into HSV color space:
import cv2
img= cv2.imread('caps.jpg')
img_HSV = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
print(img_HSV.shape)
cv2.imshow('HSVImage',img_HSV)
cv2.imshow('HueChannel', img_HSV[:, :,0])
cv2.imshow('SaturationChannel', img_HSV[:, :,1])
cv2.imshow('ValueChannel', img_HSV[:, :,2])
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# (275, 183, 3)

# %% [markdown]
# # What Is Hue?
# Hues are the three primary colors (red, blue, and yellow) and the three secondary colors (orange, green, and violet) that appear in the color wheel or color circle. When you refer to hue, you are referring to pure color, or the visible spectrum of basic colors that can be seen in a rainbow.
#
# #What Is Saturation?
# Color saturation is the purity and intensity of a color as displayed in an image. The higher the saturation of a color, the more vivid and intense it is. The lower a color’s saturation, or chroma, the closer it is to pure gray on the grayscale.

# %%
#Example of image translation:
import cv2
import numpy as np
#for reading image
img = cv2.imread("caps.jpg")
height, width = img.shape[:2]
print(height)
print(width)
quarter_height, quarter_width = height/3,width/3
print(quarter_height)
print(quarter_width)
n =  np.float32([[1,0, quarter_width], [0,1, quarter_height]])
print(n)
# We use warpAffine function  to shift the image
img_translation = cv2.warpAffine(img, n, (width, height))
cv2.imshow('originalimage',img)
cv2.imshow('AfterTranslation',img_translation)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 275
# 183
# 91.66666666666667
# 61.0
# [[ 1.        0.       61.      ]
#  [ 0.        1.       91.666664]]

# %%
import cv2
import numpy as np
img = cv2.imread("caps.jpg")
height,width = img.shape[:2]
rotation_matrix = cv2.getRotationMatrix2D((width/2,height/2), 90, .7)
rotated_image = cv2.warpAffine(img, rotation_matrix, (width,height))
cv2.imshow('Rotated Image',rotated_image)
cv2.imshow('Original image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import matplotlib.pyplot as plt
cap = cv2.VideoCapture(0)
if cap.isOpened():
 ret, frame = cap.read()
else:
 ret = False
img = cv2.cvtColor(frame,cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.title("camera image")
plt.xticks([])
plt.yticks([])
plt.show()
cap.release()

# %%
import cv2, time        #import the time module   
video= cv2.VideoCapture(0)     
time.sleep(4)         #It will stop the script for 4 seconds.   
video.release()

# %%
import cv2, time
video = cv2. VideoCapture(0)
check, frame = video.read()
print(check)
print(frame)
time.sleep (2)
video.release()
# Out:
# True
# [[[158 169 184]
#   [159 167 183]
#   [158 167 180]
#   ...
#   [119 136 151]
#   [118 135 150]
#   [116 133 148]]
#
#  [[156 167 182]
#   [158 166 182]
#   [158 167 180]
#   ...
#   [119 136 151]
#   [119 136 151]
#   [118 135 150]]
#
#  [[154 165 178]
#   [155 166 179]
#   [156 167 180]
#   ...
#   [117 136 148]
#   [118 137 149]
#   [119 138 150]]
#
#  ...
#
#  [[110 126 127]
#   [109 125 126]
#   [109 125 126]
#   ...
#   [ 69 106 119]
#   [ 68 105 118]
#   [ 67 104 117]]
#
#  [[110 124 125]
#   [109 122 125]
#   [107 123 125]
#   ...
#   [ 72 107 120]
#   [ 71 106 117]
#   [ 70 105 116]]
#
#  [[108 122 123]
#   [107 120 123]
#   [106 122 124]
#   ...
#   [ 70 105 118]
#   [ 69 104 115]
#   [ 68 103 114]]]

# %%
 
import cv2
import numpy as np
img = cv2.imread("cap.jpeg",)
cv2.imshow('Original Image',img)
cv2.waitKey(0)
canny = cv2.Canny(img, 20, 170)
cv2.imshow('canny image',canny)
cv2.waitKey(0)
# Out:
# -1

# %%
# import cv2
def sketch(image):
 img_gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
 img_gray_blur =cv2.GaussianBlur(img_gray,(5,5),0)
 canny_edge =cv2.Canny(img_gray_blur,10,70)
 ret, mask =cv2.threshold(canny_edge,70,255,cv2.THRESH_BINARY)
 return mask
cap = cv2.VideoCapture(0)
while True:
    ret, frame = cap.read()
    cv2.imshow('Our live sketch',sketch(frame))
    if cv2.waitKey(1) == 27:
        break
cap.release()
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
img = cv2.imread("cap.jpeg")
print(img.shape)
height,width = img.shape[:2]
start_row, start_col = int(height*.15),int(width*.15)
end_row, end_col = int(height*.65),int(width*.65)
cropped = img[start_row:end_row, start_col:end_col]
cv2.imshow('original image',img)
cv2.waitKey(0)
cv2.imshow('cropped image',cropped)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# (1280, 942, 3)

# %%
#Example of capturing picture using OpenCV:
import cv2
import matplotlib.pyplot as plt
cap = cv2.VideoCapture(0)
if cap.isOpened():
 ret, frame = cap.read()
else:
 ret = False
img = cv2.cvtColor(frame,cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.title("camera image")
plt.xticks([])
plt.yticks([])
plt.show()
cap.release()

# %%
import cv2
def sketch(image):
    img_gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
    img_gray_blur =cv2.GaussianBlur(img_gray,(5,5),0)
    canny_edge =cv2.Canny(img_gray_blur,10,70)
    ret, mask =cv2.threshold(canny_edge,70,255,cv2.THRESH_BINARY)
    return mask
cap = cv2.VideoCapture(0)
while True:
    ret,frame = cap.read()
    #frame= np.array(sct.grab(mon))
    plt.imshow(cv2.cvtColor(sketch(frame), cv2.COLOR_BGR2RGB))
    #plt.imshow(cv2.cvtColor(sketch(frame),cv2.COLOR_BGR2RGB))
    #plt.imshow('Ourlivesketch',sketch(frame))
    if cv2.waitKey(1) == 27:
        break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-61-90757b4232e9> in <module>
#      10     ret,frame = cap.read()
#      11     #frame= np.array(sct.grab(mon))
# ---> 12     plt.imshow(cv2.cvtColor(sketch(frame), cv2.COLOR_BGR2RGB))
#      13     #plt.imshow(cv2.cvtColor(sketch(frame),cv2.COLOR_BGR2RGB))
#      14     #plt.imshow('Ourlivesketch',sketch(frame))
#
# <ipython-input-61-90757b4232e9> in sketch(image)
#       1 import cv2
#       2 def sketch(image):
# ----> 3     img_gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
#       4     img_gray_blur =cv2.GaussianBlur(img_gray,(5,5),0)
#       5     canny_edge =cv2.Canny(img_gray_blur,10,70)
#
# error: OpenCV(4.5.1) C:\Users\appveyor\AppData\Local\Temp\1\pip-req-build-kh7iq4w7\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %% [markdown]
# from PIL import Image
# import cv2
# from PIL import Image
# import numpy as np
# from mss import mss
# import threading
# from datetime import datetime
# def thread_recording():
#
#     fourcc=cv2.VideoWriter_fourcc(*'mp4v')
#     #fourcc=cv2.VideoWriter_fourcc(*'XVID')
#     out=cv2.VideoWriter(vid_file,fourcc,50,(width,height))
#     mon = {"top": 0, "left": 0, "width":width, "height":height}
#     sct = mss()
#
#     thread1=threading.Thread(target=record,args=(mon,out,sct))
#     thread1.start()
#
# def record(mon,out,sct):
#
#     global recording
#     recording=True
#
#     while recording:
#         frame=sct.grab(mon)
#         frame = Image.frombytes('RGB', frame.size, frame.rgb)
#         frame = cv2.cvtColor(np.array(frame), cv2.COLOR_BGR2RGB)
#         out.write(np.array(frame))
#
#     out.release()

# %%
import cv2
import numpy as np

image = cv2.imread('abs.jpg')
cv2.imshow('original', image)

kernel = np.array([[-1,-1,-1],[-1, 9,-1],[-1,-1,-1]])
sharpened = cv2.filter2D(image, -1, kernel) # applying the sharpening kernel to the input image & displaying it.
cv2.imshow('Image Sharpening', sharpened)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# Out:
# -1

# %%
import cv2
import numpy as np
img = cv2.imread("abs.jpg")
print(np.array(img))
kernel_sharping = np.array([[-1,-1,-1],[-1,9,-1],[-1,-1,-1]])
sharpened = cv2.filter2D(img,-1,kernel_sharping)
#sharpened=cv2.blur(img, -1,(3,3))

cv2.imshow('original Image',img)

cv2.imshow('Sharpened Image',sharpened)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# [[[ 33 100  25]
#   [ 28  95  20]
#   [ 24  86  16]
#   ...
#   [ 76 101  41]
#   [ 56  78  20]
#   [ 38  57   2]]
#
#  [[ 23  91  14]
#   [ 20  88  11]
#   [ 18  81   7]
#   ...
#   [ 74 105  38]
#   [ 56  83  19]
#   [ 37  62   0]]
#
#  [[  5  77   0]
#   [  7  76   0]
#   [ 11  76   0]
#   ...
#   [ 63 106  25]
#   [ 48  87   9]
#   [ 31  67   0]]
#
#  ...
#
#  [[ 62  56  43]
#   [ 62  56  43]
#   [ 63  57  44]
#   ...
#   [ 16  19   4]
#   [ 14  17   2]
#   [ 12  15   0]]
#
#  [[ 56  50  37]
#   [ 56  50  37]
#   [ 57  51  38]
#   ...
#   [ 16  19   4]
#   [ 16  16   2]
#   [ 12  15   0]]
#
#  [[ 48  44  33]
#   [ 48  44  33]
#   [ 48  44  33]
#   ...
#   [ 18  18   4]
#   [ 17  16   2]
#   [ 14  14   0]]]

# %%
#Example of blur image

 
import cv2
import numpy as np
img =cv2.imread("cap.jpeg")
cv2.imshow('original image',img)
cv2.waitKey(0)
print(img.shape)
kernel = np.ones((7,7),np.float32)/49
print(kernel)
blurred = cv2.filter2D(img,-1,kernel)
cv2.imshow('blur image',blurred)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# (1280, 942, 3)
# [[0.02040816 0.02040816 0.02040816 0.02040816 0.02040816 0.02040816
#   0.02040816]
#  [0.02040816 0.02040816 0.02040816 0.02040816 0.02040816 0.02040816
#   0.02040816]
#  [0.02040816 0.02040816 0.02040816 0.02040816 0.02040816 0.02040816
#   0.02040816]
#  [0.02040816 0.02040816 0.02040816 0.02040816 0.02040816 0.02040816
#   0.02040816]
#  [0.02040816 0.02040816 0.02040816 0.02040816 0.02040816 0.02040816
#   0.02040816]
#  [0.02040816 0.02040816 0.02040816 0.02040816 0.02040816 0.02040816
#   0.02040816]
#  [0.02040816 0.02040816 0.02040816 0.02040816 0.02040816 0.02040816
#   0.02040816]]

# %%
import cv2
import numpy as np
img = cv2.imread('cap.jpeg')
rotated_image = cv2.transpose(img)
cv2.imshow('Rotated Image',rotated_image)
cv2.imshow('original image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#Example of RGB image into binary image:

import cv2
img = cv2.imread("cap.jpeg",0)
cv2.imshow("Gray image",img)
cv2.waitKey(0)
ret, bw = cv2.threshold(img,137,250,cv2.THRESH_BINARY)
cv2.imshow("Binary Image",bw)
cv2.waitKey(0)
cv2.destroyAllWindows()
